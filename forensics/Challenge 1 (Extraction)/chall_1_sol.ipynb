# %%
import csv

# %%
def csvfilereader(filename):
    with open(filename, 'r') as csvfile:
        csvreader = csv.reader(csvfile)
        head = next(csvreader)
        for line in csvreader:
            data = line[6].split(' ')
            filtered = data[4]
            filter_filtered = filtered[:50]
            print(filter_filtered, end="")
csvfilereader('justapcap.csv')
# Out:
# ....817.exfil.aexample.testrandom.data
